# %%
import pandas as pd

# %%
df = pd.read_json('ALL_extracted_initiatives_merged.json')
df.head(5)
# Out:
#   municipality_name  topic_id  \
# 0       Chapel Hill        50
# 1       Chapel Hill        51
# 2       Chapel Hill        52
# 3       Chapel Hill        53
# 4       Chapel Hill        54
#
#                                     primary_category  \
# 0                  parks, recreation, and public art
# 1  building permits, inspections, and local ordin...
# 2  town governance, human resources, and board ap...
# 3                          uncategorized initiatives
# 4  town governance, human resources, and board ap...
#
#                                       representation  budget_allocation  \
# 0  [climbing, wall, belay, belayers, center, old,...                NaN
# 1  [permit, email, steps, applicant, notification...                NaN
# 2  [community, webinar, virtual, aesthetics, advo...                NaN
# 3  [older, years, age, children, 16, 15, backgrou...                NaN
# 4  [ordinance, vote, franchise, majority, legisla...                NaN
#
#                                impacted_stakeholders  \
# 0  [community members, climbers, children, parent...
# 1  [applicants, homeowners, contractors, develope...
# 2  [Community Design Commission members, Council ...
# 3  [children, parents, volunteers, community orga...
# 4  [Town Council, residents, property owners, bus...
#
#                                              summary  related_doc_count
# 0  Chapel Hill's Community Center offers an indoo...                  3
# 1  The Chapel Hill Online Permit Center automatic...                  3
# 2  The Chapel Hill Community Design Commission, w...                  3
# 3  Chapel Hill outlines age requirements for vari...                  3
# 4  Chapel Hill's legislative procedures dictate v...                  3

# %%
# Group by municipality_name and count the number of initiatives for each municipality
municipality_counts = df.groupby('municipality_name').size().reset_index(name='counts').sort_values(by='counts', ascending=False)

# Group by primary_category and count the number of initiatives for each category
primary_category_counts = df.groupby('primary_category').size().reset_index(name='counts').sort_values(by='counts', ascending=False)

# %%
# Create a list of municipalities for filtering
municipality_list = municipality_counts['municipality_name'].tolist()

# %%
# Create a variable for each municipality and filter the DataFrame accordingly, also get counts for each primary_category within that municipality
for i, municipality in enumerate(municipality_list):
    globals()[f"{municipality.replace(' ', '_')}"] = df[df['municipality_name'] == municipality]
    print(f"Created variable {municipality.replace(' ', '_')} for municipality: {municipality} with {len(globals()[f'{municipality.replace(' ', '_')}'])} initiatives.")
    {municipality.replace(' ', '_')}
    globals()[f"counts_{municipality.replace(' ', '_')}"] =  globals()[f"{municipality.replace(' ', '_')}"].groupby('primary_category').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# Out:
# Created variable Hillsborough for municipality: Hillsborough with 82 initiatives.
# Created variable Carrboro for municipality: Carrboro with 58 initiatives.
# Created variable Chapel_Hill for municipality: Chapel Hill with 56 initiatives.
# Created variable Orange_County for municipality: Orange County with 51 initiatives.
# Created variable Mebane for municipality: Mebane with 31 initiatives.

# %%
pd.crosstab(df['primary_category'], df['municipality_name'])
# Out:
# municipality_name                                   Carrboro  Chapel Hill  \
# primary_category
# affordable housing and zoning                              2            6
# building permits, inspections, and local ordina...         0            7
# climate action and clean energy                            4            2
# job creation and business support                          1            1
# parks, recreation, and public art                          7            7
# police, fire, and emergency response                       6            3
# public transportation and roads                           10            3
# town governance, human resources, and board app...        23           20
# uncategorized initiatives                                  3            1
# waste management, stormwater, and infrastructure           2            6
#
# municipality_name                                   Hillsborough  Mebane  \
# primary_category
# affordable housing and zoning                                  0       0
# building permits, inspections, and local ordina...             6       3
# climate action and clean energy                                1       0
# job creation and business support                              3       0
# parks, recreation, and public art                              7       8
# police, fire, and emergency response                          16       6
# public transportation and roads                                5       1
# town governance, human resources, and board app...            20       5
# uncategorized initiatives                                      1       1
# waste management, stormwater, and infrastructure              23       7
#
# municipality_name                                   Orange County
# primary_category
# affordable housing and zoning                                   5
# building permits, inspections, and local ordina...              1
# climate action and clean energy                                 1
# job creation and business support                               0
# parks, recreation, and public art                               2
# police, fire, and emergency response                            5
# public transportation and roads                                 1
# town governance, human resources, and board app...             15
# uncategorized initiatives                                      19
# waste management, stormwater, and infrastructure                2
